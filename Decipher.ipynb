# %%
import itertools

def extract_letters(cipher_text, key, array_size=72):
    words = cipher_text.split()
    result = []
    for i in range(array_size):
        word_index = i % len(words)
        letter_index = key[i % len(key)] - 1
        if letter_index < len(words[word_index]):
            result.append(words[word_index][letter_index])
        else:
            result.append('*')  # Indicate out-of-bounds index
    return result

def generate_keys(max_length, max_digit):
    keys = []
    for length in range(1, max_length + 1):
        keys.extend(itertools.product(range(1, max_digit + 1), repeat=length))
    return keys

def find_possible_decryptions(cipher_text, array_size=72, max_length=6, max_digit=10):
    keys = generate_keys(max_length, max_digit)
    possible_decryptions = {}
    for key in keys:
        decryption = extract_letters(cipher_text, key, array_size)
        possible_decryptions[key] = decryption
    return possible_decryptions

cipher_text = """دمنوش مناقصه پیرارسال آبادان استقلال پاتایا ماندگاری بیکینی پارکور یزدان‌پناه دستمال بازاری مستخدم استخدام تخمینی معرفت یارکشی پینوشه تابناک کشتارگاه پرورشگاه صافکار فرامرزی گرامی‌داشت زمردیان مدرسه شبانه بیشتر بیشتر وقت‌ها تمامی مدیران اتمام کادر یاوران آسیاب زغالی کشتی پاره دلاور لوکوموتیو پخته مگسی کنار مشعل پرتغالی‌ها فرگشت سهل‌انگاری کلاف هسته‌ای تداوم پویش آدمی اولین شکارچیان قیمه‌پزون دراماتیک بیچاره افتتاح خرمگس توییتری تصفیه تراکنش بانکی نظام پیکاسو باهاما مکالمه سیرجان اصفهان الماسیان افتاد؟"""

possible_decryptions = find_possible_decryptions(cipher_text, max_length=6)

# Limit the number of results displayed
max_results = 10000
count = 0

for key, decryption in possible_decryptions.items():
    decrypted_text = ''.join(decryption)
    if decrypted_text.startswith('شاید'):
        if count >= max_results:
            break
        print(f"Key: {key} -> Decryption: {decrypted_text}")
        count += 1
# Out:
# Key: (5, 3, 2, 4) -> Decryption: شایدلتایودسادتخفشنااشفرمیربترتمرمداایتاومتگر*تر‌*تدش*لکهاچفگتفرک*کالافلا
# Key: (5, 3, 2, 4, 1) -> Decryption: شایداینیکیازسختترینکشفرمزهایتوییتریباشهدمتگرماگهفهمیدیش‌ایتختفرکنسهکجاست
# Key: (5, 3, 2, 4, 2) -> Decryption: شایدسینیکزازسخخترینششفرممهایتقییتراباشهلمتگرشاگهفسمیدیک‌ایترتفرکظسهکجصست
# Key: (5, 3, 2, 4, 3) -> Decryption: شایدتینیکدازسخمترینتشفرمرهایتتییتروباشهامتگرعاگهفتمیدیا‌ایتمتفرکاسهکجفست
# Key: (5, 3, 2, 4, 4) -> Decryption: شایدقینیکاازسخیتریناشفرمدهایت‌ییتررباشهومتگرلاگهفهمیدیر‌ایتگتفرکمسهکجهست
# Key: (5, 3, 2, 4, 5) -> Decryption: شایدلینیکنازسخنترینرشفرمیهایتهییتراباشهرمتگر*اگهف‌میدیچ‌ایتستفرک*سهکجاست
# Key: (5, 3, 2, 4, 6) -> Decryption: شایداینیک‌ازسخیترینگشفرماهایتاییترنباشه*متگر*اگهفامیدیی‌ایت*تفرک*سهکجنست
# Key: (5, 3, 2, 4, 7) -> Decryption: شایدلینیکپازسخ*تریناشفرمنهایت*ییتر*باشه*متگر*اگهفیمیدیا‌ایت*تفرک*سهکج*ست
# Key: (5, 3, 2, 4, 8) -> Decryption: شاید*ینیکنازسخ*ترینهشفرم*هایت*ییتر*باشه*متگر*اگهف*میدین‌ایت*تفرک*سهکج*ست
# Key: (5, 3, 2, 4, 9) -> Decryption: شاید*ینیکاازسخ*ترین*شفرم*هایت*ییتر*باشه*متگر*اگهف*میدی*‌ایت*تفرک*سهکج*ست
# Key: (5, 3, 2, 4, 10) -> Decryption: شاید*ینیکهازسخ*ترین*شفرم*هایت*ییتر*باشه*متگر*اگهف*میدی*‌ایت*تفرک*سهکج*ست
# Key: (5, 3, 2, 4, 1, 1) -> Decryption: شایداپگکاادبدتخفیپاترکفگیربتبوییتریآیتاولپ*اشغفس*تدشآاچمرااختفرکنپمایهاا
# Key: (5, 3, 2, 4, 1, 2) -> Decryption: شایدااگکاادادتخفییاترکفریربتبقییتریسیتاولخ*اشغفه*تدشآوچمراارتفرکنیمایهاف
# Key: (5, 3, 2, 4, 1, 3) -> Decryption: شایداتگکاادزدتخفیناترکفایربتبتییتریییتاولت*اشغفل*تدشآلچمراامتفرکنکمایهات
# Key: (5, 3, 2, 4, 1, 4) -> Decryption: شایدااگکاادادتخفیواترکفمیربتب‌ییتریایتاوله*اشغف‌*تدشآیچمرااگتفرکنامایهاا
# Key: (5, 3, 2, 4, 1, 5) -> Decryption: شایدایگکاادردتخفیشاترکفییربتبهییتریبیتاول**اشغفا*تدشآنچمرااستفرکنسمایهاد
# Key: (5, 3, 2, 4, 1, 6) -> Decryption: شایدااگکاادیدتخفیهاترکف‌یربتباییتری*یتاول**اشغفن*تدشآ*چمراا*تفرکنومایها؟
# Key: (5, 3, 2, 4, 1, 7) -> Decryption: شایدا*گکااد*دتخفی*اترکفدیربتب*ییتری*یتاول**اشغفگ*تدشآ*چمراا*تفرکن*مایها*
# Key: (5, 3, 2, 4, 1, 8) -> Decryption: شایدا*گکااد*دتخفی*اترکفایربتب*ییتری*یتاول**اشغفا*تدشآ*چمراا*تفرکن*مایها*
# Key: (5, 3, 2, 4, 1, 9) -> Decryption: شایدا*گکااد*دتخفی*اترکفشیربتب*ییتری*یتاول**اشغفر*تدشآ*چمراا*تفرکن*مایها*
# Key: (5, 3, 2, 4, 1, 10) -> Decryption: شایدا*گکااد*دتخفی*اترکفتیربتب*ییتری*یتاول**اشغفی*تدشآ*چمراا*تفرکن*مایها*
# Key: (5, 3, 2, 4, 2, 1) -> Decryption: شایدسپگکااسبدتخفاپاترکرگیربتیوییتراآیتاووپ*اشغرس*تدشداچمرافختفرکظپمایهلا
# Key: (5, 3, 2, 4, 2, 2) -> Decryption: شایدساگکااسادتخفایاترکرریربتیقییتراسیتاووخ*اشغره*تدشدوچمرافرتفرکظیمایهلف
# Key: (5, 3, 2, 4, 2, 3) -> Decryption: شایدستگکااسزدتخفاناترکرایربتیتییتراییتاووت*اشغرل*تدشدلچمرافمتفرکظکمایهلت
# Key: (5, 3, 2, 4, 2, 4) -> Decryption: شایدساگکااسادتخفاواترکرمیربتی‌ییتراایتاووه*اشغر‌*تدشدیچمرافگتفرکظامایهلا
# Key: (5, 3, 2, 4, 2, 5) -> Decryption: شایدسیگکااسردتخفاشاترکرییربتیهییترابیتاوو**اشغرا*تدشدنچمرافستفرکظسمایهلد
# Key: (5, 3, 2, 4, 2, 6) -> Decryption: شایدساگکااسیدتخفاهاترکر‌یربتیاییترا*یتاوو**اشغرن*تدشد*چمراف*تفرکظومایهل؟
# Key: (5, 3, 2, 4, 2, 7) -> Decryption: شایدس*گکااس*دتخفا*اترکردیربتی*ییترا*یتاوو**اشغرگ*تدشد*چمراف*تفرکظ*مایهل*
# Key: (5, 3, 2, 4, 2, 8) -> Decryption: شایدس*گکااس*دتخفا*اترکرایربتی*ییترا*یتاوو**اشغرا*تدشد*چمراف*تفرکظ*مایهل*
# Key: (5, 3, 2, 4, 2, 9) -> Decryption: شایدس*گکااس*دتخفا*اترکرشیربتی*ییترا*یتاوو**اشغرر*تدشد*چمراف*تفرکظ*مایهل*
# Key: (5, 3, 2, 4, 2, 10) -> Decryption: شایدس*گکااس*دتخفا*اترکرتیربتی*ییترا*یتاوو**اشغری*تدشد*چمراف*تفرکظ*مایهل*
# Key: (5, 3, 2, 4, 3, 1) -> Decryption: شایدتپگکااتبدتخفرپاترکاگیربتشوییتروآیتاوکپ*اشغگس*تدشماچمراتختفرکاپمایهما
# Key: (5, 3, 2, 4, 3, 2) -> Decryption: شایدتاگکااتادتخفریاترکاریربتشقییتروسیتاوکخ*اشغگه*تدشموچمراترتفرکایمایهمف
# Key: (5, 3, 2, 4, 3, 3) -> Decryption: شایدتتگکااتزدتخفرناترکاایربتشتییتروییتاوکت*اشغگل*تدشملچمراتمتفرکاکمایهمت
# Key: (5, 3, 2, 4, 3, 4) -> Decryption: شایدتاگکااتادتخفرواترکامیربتش‌ییتروایتاوکه*اشغگ‌*تدشمیچمراتگتفرکاامایهما
# Key: (5, 3, 2, 4, 3, 5) -> Decryption: شایدتیگکااتردتخفرشاترکاییربتشهییتروبیتاوک**اشغگا*تدشمنچمراتستفرکاسمایهمد
# Key: (5, 3, 2, 4, 3, 6) -> Decryption: شایدتاگکااتیدتخفرهاترکا‌یربتشاییترو*یتاوک**اشغگن*تدشم*چمرات*تفرکاومایهم؟
# Key: (5, 3, 2, 4, 3, 7) -> Decryption: شایدت*گکاات*دتخفر*اترکادیربتش*ییترو*یتاوک**اشغگگ*تدشم*چمرات*تفرکا*مایهم*
# Key: (5, 3, 2, 4, 3, 8) -> Decryption: شایدت*گکاات*دتخفر*اترکاایربتش*ییترو*یتاوک**اشغگا*تدشم*چمرات*تفرکا*مایهم*
# Key: (5, 3, 2, 4, 3, 9) -> Decryption: شایدت*گکاات*دتخفر*اترکاشیربتش*ییترو*یتاوک**اشغگر*تدشم*چمرات*تفرکا*مایهم*
# Key: (5, 3, 2, 4, 3, 10) -> Decryption: شایدت*گکاات*دتخفر*اترکاتیربتش*ییترو*یتاوک**اشغگی*تدشم*چمرات*تفرکا*مایهم*
# Key: (5, 3, 2, 4, 4, 1) -> Decryption: شایدقپگکاامبدتخفکپاترکمگیربتتوییتررآیتاووپ*اشغشس*تدشیاچمراتختفرکمپمایهاا
# Key: (5, 3, 2, 4, 4, 2) -> Decryption: شایدقاگکاامادتخفکیاترکمریربتتقییتررسیتاووخ*اشغشه*تدشیوچمراترتفرکمیمایهاف
# Key: (5, 3, 2, 4, 4, 3) -> Decryption: شایدقتگکاامزدتخفکناترکمایربتتتییتررییتاووت*اشغشل*تدشیلچمراتمتفرکمکمایهات
# Key: (5, 3, 2, 4, 4, 4) -> Decryption: شایدقاگکاامادتخفکواترکممیربتت‌ییتررایتاووه*اشغش‌*تدشییچمراتگتفرکمامایهاا
# Key: (5, 3, 2, 4, 4, 5) -> Decryption: شایدقیگکاامردتخفکشاترکمییربتتهییترربیتاوو**اشغشا*تدشینچمراتستفرکمسمایهاد
# Key: (5, 3, 2, 4, 4, 6) -> Decryption: شایدقاگکاامیدتخفکهاترکم‌یربتتاییترر*یتاوو**اشغشن*تدشی*چمرات*تفرکمومایها؟
# Key: (5, 3, 2, 4, 4, 7) -> Decryption: شایدق*گکاام*دتخفک*اترکمدیربتت*ییترر*یتاوو**اشغشگ*تدشی*چمرات*تفرکم*مایها*
# Key: (5, 3, 2, 4, 4, 8) -> Decryption: شایدق*گکاام*دتخفک*اترکمایربتت*ییترر*یتاوو**اشغشا*تدشی*چمرات*تفرکم*مایها*
# Key: (5, 3, 2, 4, 4, 9) -> Decryption: شایدق*گکاام*دتخفک*اترکمشیربتت*ییترر*یتاوو**اشغشر*تدشی*چمرات*تفرکم*مایها*
# Key: (5, 3, 2, 4, 4, 10) -> Decryption: شایدق*گکاام*دتخفک*اترکمتیربتت*ییترر*یتاوو**اشغشی*تدشی*چمرات*تفرکم*مایها*
# Key: (5, 3, 2, 4, 5, 1) -> Decryption: شایدلپگکااابدتخفشپاترکرگیربتروییتراآیتاومپ*اشغتس*تدش*اچمرااختفرک*پمایهسا
# Key: (5, 3, 2, 4, 5, 2) -> Decryption: شایدلاگکاااادتخفشیاترکرریربترقییتراسیتاومخ*اشغته*تدش*وچمراارتفرک*یمایهسف
# Key: (5, 3, 2, 4, 5, 3) -> Decryption: شایدلتگکااازدتخفشناترکرایربترتییتراییتاومت*اشغتل*تدش*لچمراامتفرک*کمایهست
# Key: (5, 3, 2, 4, 5, 4) -> Decryption: شایدلاگکاااادتخفشواترکرمیربتر‌ییتراایتاومه*اشغت‌*تدش*یچمرااگتفرک*امایهسا
# Key: (5, 3, 2, 4, 5, 5) -> Decryption: شایدلیگکاااردتخفششاترکرییربترهییترابیتاوم**اشغتا*تدش*نچمرااستفرک*سمایهسد
# Key: (5, 3, 2, 4, 5, 6) -> Decryption: شایدلاگکااایدتخفشهاترکر‌یربتراییترا*یتاوم**اشغتن*تدش**چمراا*تفرک*ومایهس؟
# Key: (5, 3, 2, 4, 5, 7) -> Decryption: شایدل*گکااا*دتخفش*اترکردیربتر*ییترا*یتاوم**اشغتگ*تدش**چمراا*تفرک**مایهس*
# Key: (5, 3, 2, 4, 5, 8) -> Decryption: شایدل*گکااا*دتخفش*اترکرایربتر*ییترا*یتاوم**اشغتا*تدش**چمراا*تفرک**مایهس*
# Key: (5, 3, 2, 4, 5, 9) -> Decryption: شایدل*گکااا*دتخفش*اترکرشیربتر*ییترا*یتاوم**اشغتر*تدش**چمراا*تفرک**مایهس*
# Key: (5, 3, 2, 4, 5, 10) -> Decryption: شایدل*گکااا*دتخفش*اترکرتیربتر*ییترا*یتاوم**اشغتی*تدش**چمراا*تفرک**مایهس*
# Key: (5, 3, 2, 4, 6, 1) -> Decryption: شایداپگکاالبدتخفیپاترکزگیربت*وییترنآیتاووپ*اشغ*س*تدش*اچمراحختفرک*پمایهیا
# Key: (5, 3, 2, 4, 6, 2) -> Decryption: شایدااگکاالادتخفییاترکزریربت*قییترنسیتاووخ*اشغ*ه*تدش*وچمراحرتفرک*یمایهیف
# Key: (5, 3, 2, 4, 6, 3) -> Decryption: شایداتگکاالزدتخفیناترکزایربت*تییترنییتاووت*اشغ*ل*تدش*لچمراحمتفرک*کمایهیت
# Key: (5, 3, 2, 4, 6, 4) -> Decryption: شایدااگکاالادتخفیواترکزمیربت*‌ییترنایتاووه*اشغ*‌*تدش*یچمراحگتفرک*امایهیا
# Key: (5, 3, 2, 4, 6, 5) -> Decryption: شایدایگکاالردتخفیشاترکزییربت*هییترنبیتاوو**اشغ*ا*تدش*نچمراحستفرک*سمایهید
# Key: (5, 3, 2, 4, 6, 6) -> Decryption: شایدااگکاالیدتخفیهاترکز‌یربت*اییترن*یتاوو**اشغ*ن*تدش**چمراح*تفرک*ومایهی؟
# Key: (5, 3, 2, 4, 6, 7) -> Decryption: شایدا*گکاال*دتخفی*اترکزدیربت**ییترن*یتاوو**اشغ*گ*تدش**چمراح*تفرک**مایهی*
# Key: (5, 3, 2, 4, 6, 8) -> Decryption: شایدا*گکاال*دتخفی*اترکزایربت**ییترن*یتاوو**اشغ*ا*تدش**چمراح*تفرک**مایهی*
# Key: (5, 3, 2, 4, 6, 9) -> Decryption: شایدا*گکاال*دتخفی*اترکزشیربت**ییترن*یتاوو**اشغ*ر*تدش**چمراح*تفرک**مایهی*
# Key: (5, 3, 2, 4, 6, 10) -> Decryption: شایدا*گکاال*دتخفی*اترکزتیربت**ییترن*یتاوو**اشغ*ی*تدش**چمراح*تفرک**مایهی*
# Key: (5, 3, 2, 4, 7, 1) -> Decryption: شایدلپگکاا*بدتخف*پاترکیگیربت*وییتر*آیتاوتپ*اشغ*س*تدش*اچمرا*ختفرک*پمایهاا
# Key: (5, 3, 2, 4, 7, 2) -> Decryption: شایدلاگکاا*ادتخف*یاترکیریربت*قییتر*سیتاوتخ*اشغ*ه*تدش*وچمرا*رتفرک*یمایهاف
# Key: (5, 3, 2, 4, 7, 3) -> Decryption: شایدلتگکاا*زدتخف*ناترکیایربت*تییتر*ییتاوتت*اشغ*ل*تدش*لچمرا*متفرک*کمایهات
# Key: (5, 3, 2, 4, 7, 4) -> Decryption: شایدلاگکاا*ادتخف*واترکیمیربت*‌ییتر*ایتاوته*اشغ*‌*تدش*یچمرا*گتفرک*امایهاا
# Key: (5, 3, 2, 4, 7, 5) -> Decryption: شایدلیگکاا*ردتخف*شاترکیییربت*هییتر*بیتاوت**اشغ*ا*تدش*نچمرا*ستفرک*سمایهاد
# Key: (5, 3, 2, 4, 7, 6) -> Decryption: شایدلاگکاا*یدتخف*هاترکی‌یربت*اییتر**یتاوت**اشغ*ن*تدش**چمرا**تفرک*ومایها؟
# Key: (5, 3, 2, 4, 7, 7) -> Decryption: شایدل*گکاا**دتخف**اترکیدیربت**ییتر**یتاوت**اشغ*گ*تدش**چمرا**تفرک**مایها*
# Key: (5, 3, 2, 4, 7, 8) -> Decryption: شایدل*گکاا**دتخف**اترکیایربت**ییتر**یتاوت**اشغ*ا*تدش**چمرا**تفرک**مایها*
# Key: (5, 3, 2, 4, 7, 9) -> Decryption: شایدل*گکاا**دتخف**اترکیشیربت**ییتر**یتاوت**اشغ*ر*تدش**چمرا**تفرک**مایها*
# Key: (5, 3, 2, 4, 7, 10) -> Decryption: شایدل*گکاا**دتخف**اترکیتیربت**ییتر**یتاوت**اشغ*ی*تدش**چمرا**تفرک**مایها*
# Key: (5, 3, 2, 4, 8, 1) -> Decryption: شاید*پگکاا*بدتخف*پاترک*گیربت*وییتر*آیتاویپ*اشغ*س*تدش*اچمرا*ختفرک*پمایهنا
# Key: (5, 3, 2, 4, 8, 2) -> Decryption: شاید*اگکاا*ادتخف*یاترک*ریربت*قییتر*سیتاویخ*اشغ*ه*تدش*وچمرا*رتفرک*یمایهنف
# Key: (5, 3, 2, 4, 8, 3) -> Decryption: شاید*تگکاا*زدتخف*ناترک*ایربت*تییتر*ییتاویت*اشغ*ل*تدش*لچمرا*متفرک*کمایهنت
# Key: (5, 3, 2, 4, 8, 4) -> Decryption: شاید*اگکاا*ادتخف*واترک*میربت*‌ییتر*ایتاویه*اشغ*‌*تدش*یچمرا*گتفرک*امایهنا
# Key: (5, 3, 2, 4, 8, 5) -> Decryption: شاید*یگکاا*ردتخف*شاترک*ییربت*هییتر*بیتاوی**اشغ*ا*تدش*نچمرا*ستفرک*سمایهند
# Key: (5, 3, 2, 4, 8, 6) -> Decryption: شاید*اگکاا*یدتخف*هاترک*‌یربت*اییتر**یتاوی**اشغ*ن*تدش**چمرا**تفرک*ومایهن؟
# Key: (5, 3, 2, 4, 8, 7) -> Decryption: شاید**گکاا**دتخف**اترک*دیربت**ییتر**یتاوی**اشغ*گ*تدش**چمرا**تفرک**مایهن*
# Key: (5, 3, 2, 4, 8, 8) -> Decryption: شاید**گکاا**دتخف**اترک*ایربت**ییتر**یتاوی**اشغ*ا*تدش**چمرا**تفرک**مایهن*
# Key: (5, 3, 2, 4, 8, 9) -> Decryption: شاید**گکاا**دتخف**اترک*شیربت**ییتر**یتاوی**اشغ*ر*تدش**چمرا**تفرک**مایهن*
# Key: (5, 3, 2, 4, 8, 10) -> Decryption: شاید**گکاا**دتخف**اترک*تیربت**ییتر**یتاوی**اشغ*ی*تدش**چمرا**تفرک**مایهن*
# Key: (5, 3, 2, 4, 9, 1) -> Decryption: شاید*پگکاا*بدتخف*پاترک*گیربت*وییتر*آیتاووپ*اشغ*س*تدش*اچمرا*ختفرک*پمایه*ا
# Key: (5, 3, 2, 4, 9, 2) -> Decryption: شاید*اگکاا*ادتخف*یاترک*ریربت*قییتر*سیتاووخ*اشغ*ه*تدش*وچمرا*رتفرک*یمایه*ف
# Key: (5, 3, 2, 4, 9, 3) -> Decryption: شاید*تگکاا*زدتخف*ناترک*ایربت*تییتر*ییتاووت*اشغ*ل*تدش*لچمرا*متفرک*کمایه*ت
# Key: (5, 3, 2, 4, 9, 4) -> Decryption: شاید*اگکاا*ادتخف*واترک*میربت*‌ییتر*ایتاووه*اشغ*‌*تدش*یچمرا*گتفرک*امایه*ا
# Key: (5, 3, 2, 4, 9, 5) -> Decryption: شاید*یگکاا*ردتخف*شاترک*ییربت*هییتر*بیتاوو**اشغ*ا*تدش*نچمرا*ستفرک*سمایه*د
# Key: (5, 3, 2, 4, 9, 6) -> Decryption: شاید*اگکاا*یدتخف*هاترک*‌یربت*اییتر**یتاوو**اشغ*ن*تدش**چمرا**تفرک*ومایه*؟
# Key: (5, 3, 2, 4, 9, 7) -> Decryption: شاید**گکاا**دتخف**اترک*دیربت**ییتر**یتاوو**اشغ*گ*تدش**چمرا**تفرک**مایه**
# Key: (5, 3, 2, 4, 9, 8) -> Decryption: شاید**گکاا**دتخف**اترک*ایربت**ییتر**یتاوو**اشغ*ا*تدش**چمرا**تفرک**مایه**
# Key: (5, 3, 2, 4, 9, 9) -> Decryption: شاید**گکاا**دتخف**اترک*شیربت**ییتر**یتاوو**اشغ*ر*تدش**چمرا**تفرک**مایه**
# Key: (5, 3, 2, 4, 9, 10) -> Decryption: شاید**گکاا**دتخف**اترک*تیربت**ییتر**یتاوو**اشغ*ی*تدش**چمرا**تفرک**مایه**
# Key: (5, 3, 2, 4, 10, 1) -> Decryption: شاید*پگکاا*بدتخف*پاترک*گیربت*وییتر*آیتاو*پ*اشغ*س*تدش*اچمرا*ختفرک*پمایه*ا
# Key: (5, 3, 2, 4, 10, 2) -> Decryption: شاید*اگکاا*ادتخف*یاترک*ریربت*قییتر*سیتاو*خ*اشغ*ه*تدش*وچمرا*رتفرک*یمایه*ف
# Key: (5, 3, 2, 4, 10, 3) -> Decryption: شاید*تگکاا*زدتخف*ناترک*ایربت*تییتر*ییتاو*ت*اشغ*ل*تدش*لچمرا*متفرک*کمایه*ت
# Key: (5, 3, 2, 4, 10, 4) -> Decryption: شاید*اگکاا*ادتخف*واترک*میربت*‌ییتر*ایتاو*ه*اشغ*‌*تدش*یچمرا*گتفرک*امایه*ا
# Key: (5, 3, 2, 4, 10, 5) -> Decryption: شاید*یگکاا*ردتخف*شاترک*ییربت*هییتر*بیتاو***اشغ*ا*تدش*نچمرا*ستفرک*سمایه*د
# Key: (5, 3, 2, 4, 10, 6) -> Decryption: شاید*اگکاا*یدتخف*هاترک*‌یربت*اییتر**یتاو***اشغ*ن*تدش**چمرا**تفرک*ومایه*؟
# Key: (5, 3, 2, 4, 10, 7) -> Decryption: شاید**گکاا**دتخف**اترک*دیربت**ییتر**یتاو***اشغ*گ*تدش**چمرا**تفرک**مایه**
# Key: (5, 3, 2, 4, 10, 8) -> Decryption: شاید**گکاا**دتخف**اترک*ایربت**ییتر**یتاو***اشغ*ا*تدش**چمرا**تفرک**مایه**
# Key: (5, 3, 2, 4, 10, 9) -> Decryption: شاید**گکاا**دتخف**اترک*شیربت**ییتر**یتاو***اشغ*ر*تدش**چمرا**تفرک**مایه**
# Key: (5, 3, 2, 4, 10, 10) -> Decryption: شاید**گکاا**دتخف**اترک*تیربت**ییتر**یتاو***اشغ*ی*تدش**چمرا**تفرک**مایه**

# %%
import itertools

def extract_letters(cipher_text, key, array_size=72):
    words = cipher_text.split()
    result = []
    for i in range(array_size):
        word_index = i % len(words)
        letter_index = key[i % len(key)] - 1
        if letter_index < len(words[word_index]):
            result.append(words[word_index][letter_index])
        else:
            result.append('*')  # Indicate out-of-bounds index
    return result

def generate_keys(max_length, max_digit):
    keys = []
    for length in range(1, max_length + 1):
        keys.extend(itertools.product(range(1, max_digit + 1), repeat=length))
    return keys

def find_possible_decryptions(cipher_text, array_size=72, max_length=6, max_digit=5):
    keys = generate_keys(max_length, max_digit)
    possible_decryptions = {}
    for key in keys:
        decryption = extract_letters(cipher_text, key, array_size)
        possible_decryptions[key] = decryption
    return possible_decryptions

cipher_text = """دمنوش مناقصه پیرارسال آبادان استقلال پاتایا ماندگاری بیکینی پارکور یزدان‌پناه دستمال بازاری مستخدم استخدام تخمینی معرفت یارکشی پینوشه تابناک کشتارگاه پرورشگاه صافکار فرامرزی گرامی‌داشت زمردیان مدرسه شبانه بیشتر بیشتر وقت‌ها تمامی مدیران اتمام کادر یاوران آسیاب زغالی کشتی پاره دلاور لوکوموتیو پخته مگسی کنار مشعل پرتغالی‌ها فرگشت سهل‌انگاری کلاف هسته‌ای تداوم پویش آدمی اولین شکارچیان قیمه‌پزون دراماتیک بیچاره افتتاح خرمگس توییتری تصفیه تراکنش بانکی نظام پیکاسو باهاما مکالمه سیرجان اصفهان الماسیان افتاد؟"""

possible_decryptions = find_possible_decryptions(cipher_text, max_length=6)

# Limit the number of results displayed
max_results = 50
count = 0

for key, decryption in possible_decryptions.items():
    decrypted_text = ''.join(decryption)
    if  decrypted_text.endswith('کجاست'):
        if count >= max_results:
            break
        print(f"Key: {key} -> Decryption: {decrypted_text}")
        count += 1
# Out:
# Key: (5, 3, 2, 4, 1) -> Decryption: شایداینیکیازسختترینکشفرمزهایتوییتریباشهدمتگرماگهفهمیدیش‌ایتختفرکنسهکجاست
# Key: (5, 3, 2, 4, 5) -> Decryption: شایدلینیکنازسخنترینرشفرمیهایتهییتراباشهرمتگر*اگهف‌میدیچ‌ایتستفرک*سهکجاست
# Key: (1, 2, 4, 1, 5, 3) -> Decryption: دناآلتمیکیازمسیمشنتشرصرازدنبرتتداکایزشهدمتمنلپتلکسوپ*لشیمبامتصکب*کبکجاست
# Key: (1, 2, 4, 5, 5, 3) -> Decryption: دناالتمیکنازمسیتشنتشرارازدنررتتدا*ایزشهرمتمنلاتلکسو**لشیمرامتصکی*کبکجاست
# Key: (2, 2, 4, 1, 5, 3) -> Decryption: مناآلتایکیازسسیمشناشرصرامدنبرتمداکایغشهدمتگنلپتللسوپ*لکیمباموصکب*کاکجاست
# Key: (2, 2, 4, 5, 5, 3) -> Decryption: مناالتایکنازسسیتشناشرارامدنررتمدا*ایغشهرمتگنلاتللسو**لکیمراموصکی*کاکجاست
# Key: (3, 2, 4, 1, 5, 3) -> Decryption: نناآلتنیکیازتسیمشنبشرصراردنبرتاداکایاشهدمتسنلپتلاسوپ*لایمبامیصکب*کهکجاست
# Key: (3, 2, 4, 5, 5, 3) -> Decryption: نناالتنیکنازتسیتشنبشراراردنررتادا*ایاشهرمتسنلاتلاسو**لایمرامیصکی*کهکجاست
# Key: (4, 2, 4, 1, 5, 3) -> Decryption: وناآلتدیکیازخسیمشننشرصراددنبرتمداکایلشهدمتینلپتلفسوپ*لریمبامیصکب*کاکجاست
# Key: (4, 2, 4, 5, 5, 3) -> Decryption: وناالتدیکنازخسیتشننشراراددنررتمدا*ایلشهرمتینلاتلفسو**لریمرامیصکی*کاکجاست
# Key: (5, 2, 4, 1, 5, 3) -> Decryption: شناآلتگیکیازدسیمشناشرصرایدنبرتیداکاییشهدمت*نلپتل*سوپ*لچیمبامتصکب*کمکجاست
# Key: (5, 2, 4, 5, 5, 3) -> Decryption: شناالتگیکنازدسیتشناشرارایدنررتیدا*اییشهرمت*نلاتل*سو**لچیمرامتصکی*کمکجاست
